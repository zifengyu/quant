# %%
import pickle

# %%
result_dict = pickle.load(open("breakout/510050_20100101_20161231/n5.pkl", "rb"))

# %%
result_dict.keys()
# Out:
# dict_keys(['summary', 'stock_positions', 'trades', 'benchmark_portfolio', 'portfolio', 'stock_account'])

# %%
result_dict['portfolio']
# Out:
#                   cash  market_value  static_unit_net_value  total_value  \
# date
# 2010-01-04  100000.000           0.0                  1.000   100000.000
# 2010-01-05  100000.000           0.0                  1.000   100000.000
# 2010-01-06  100000.000           0.0                  1.000   100000.000
# 2010-01-07  100000.000           0.0                  1.000   100000.000
# 2010-01-08  100000.000           0.0                  1.000   100000.000
# 2010-01-11  100000.000           0.0                  1.000   100000.000
# 2010-01-12  100000.000           0.0                  1.000   100000.000
# 2010-01-13  100000.000           0.0                  1.000   100000.000
# 2010-01-14  100000.000           0.0                  1.000   100000.000
# 2010-01-15  100000.000           0.0                  1.000   100000.000
# 2010-01-18  100000.000           0.0                  1.000   100000.000
# 2010-01-19  100000.000           0.0                  1.000   100000.000
# ...

# %%
result_dict['trades']
# Out:
#                      commission     exec_id  last_price  last_quantity  \
# datetime
# 2010-02-04 15:00:00     7.77784  1495543263       2.261           4300
# 2010-02-26 15:00:00     7.83976  1495543264       2.279           4300
# 2010-03-02 15:00:00     7.98080  1495543265       2.320           4300
# 2010-03-05 15:00:00     7.81568  1495543266       2.272           4300
# 2010-03-18 15:00:00     7.93264  1495543267       2.306           4300
# 2010-03-26 15:00:00     7.76064  1495543268       2.256           4300
# 2010-03-30 15:00:00     7.94976  1495543269       2.366           4200
# 2010-04-09 15:00:00     7.81200  1495543270       2.325           4200
# 2010-04-15 15:00:00     7.97328  1495543271       2.373           4200
# 2010-04-19 15:00:00     7.74480  1495543272       2.305           4200
# 2010-05-14 15:00:00     7.78752  1495543273       2.028           4800
# 2010-05-18 15:00:00     7.45344  1495543274       1.941           4800
# ...
